# %% [markdown]
# # 9. GAN
# This section will be an exercise. Surprisingly, you can build GAN fairly easily just by using the concepts we learned so far.
#
# ## Preparation
# Read section 1, 2, 3 of the original [GAN paper](https://arxiv.org/pdf/1406.2661.pdf). Then, follow the next 7 steps to implement GAN.
#
# To summarie, we have the following problem setup:
# - $x$: data with distribution $p_{data}$
# - $p_g$: distribution trained by the generator
# - $z$: prior input noise variables
# - $p_z$: prior of $z$
# - $G(z;\theta_G)$: generator neural network with parameter $\theta_G$
# - $D(z;\theta_D)$: discriminator neural network with parameter $\theta_D$
#
# The goal for $D,G$ are the following:
# - $D$: $max_D V(D) = E_{x\sim p_{data}}(x)[logD(x)] + E_{z\sim p_z(z)}[log(1-D(G(z))]$
# - $G$: $min_G V(G) = E_{z\sim p_z(z)}[log(1-D(G(z))]$

# %%
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# We pre-selected the hyper parameters for you this time. You usually need to tune this yourself.

# %%
# Training Params
num_steps = 500000
batch_size = 128
learning_rate = 0.0002

# %% [markdown]
# The hidden dimensions of the generator and the discriminator are also prespecified.

# %%
# Network Params
image_dim = 784 # 28*28 pixels
gen_hidden_dim = 256
disc_hidden_dim = 256
noise_dim = 100 # Noise data points

# %%
tf.reset_default_graph() # Clearing all tensors before this

# %% [markdown]
# ### 1. Implement generator and discriminator.
#
# Let both G and D be a 1-hidden layer fully connected neural network. Use ReLU for activation function for the hidden layer. For out layer, you should know what to use :)
# Since G and D are both 1-hidden layer fully connected NN, we need
# - weights for hidden layer and out layer
# - bias for hidden layer and out layer
#
# for each. Use `tf.layers.dense`.
#
# Becareful about the dimensions of the layers:
# - $G$ takes in noise and generates an image.
# - $D$ takes in an image and outputs a probability of the image being real.

# %%
# Generator
def generator(noises, reuse=False):
    with tf.variable_scope('generator') as scope:
        if (reuse):
            tf.get_variable_scope().reuse_variables()
        # TODO hidden layer with name "g_hidden"
        # TODO out layer with name "g_out"
    return out_images

# Discriminator
def discriminator(images, reuse=False):
    with tf.variable_scope('discriminator') as scope:
        if (reuse):
            tf.get_variable_scope().reuse_variables()
        # TODO hidden layer with name "d_hidden"
        # TODO out layer with name "d_out"
    return out_prob

# %% [markdown]
# ### 2. Define the inputs to generator and discriminator.
# - Input to G: (batch size) $\times$ ??
# - Input to D: (batch size) $\times$ ??
#
# Think about what ?? should be.

# %% [markdown]
# ### 3. Input noise to G and generate images.
# This should be a one linear.

# %% [markdown]
# ### 3. Input real and fake images to D and get predictions.
# For D, you should have two inputs: real data and fake data. The latter is the output of $G$. For the latter, set `reuse=True`. I won't go into detail about it, but basically, you are reusing the samve variables in the above `discriminator` function and so you want to make them reusable.

# %% [markdown]
# ### 4. Define the objective.
# Expectation should be approximated using the sample mean. As a reminder, they are:
# - $D$: $max_D V(D) = E_{x\sim p_{data}}(x)[logD(x)] + E_{z\sim p_z(z)}[log(1-D(G(z))]$
# - $G$: $min_G V(G) = E_{z\sim p_z(z)}[log(1-D(G(z))]$

# %% [markdown]
# ### 5. Minimize (or maximize) the objective.
# Adam optimizer is recommended. We should have two optimizers for D and G. Be careful to only take the gradient with respect to the variables to optimize. Namely
# - $V(D)$: weights and biases of D
# - $V(G)$: weights and biases of G
#
# We provided the code for extracting these variables from the computation graph.

# %%
tvars = tf.trainable_variables()
disc_vars = [var for var in tvars if 'd_' in var.name]
gen_vars = [var for var in tvars if 'g_' in var.name]

# %%
# TODO

# %% [markdown]
# ### 6. Train the model.
# For each iteration, take some batch of MNIST. Generate a prior noise $z$ by `np.random.uniform(-1., 1., size=[batch_size, noise_dim])`. Feed the batch data and prior noise to the model to update the objective.
#
# After some epochs of training, for each noise generated, get the output $x$ by the generator and plot it using matplotlib. This time we prepared the code for you but read through it to understand it. Then, change the variable names if they are different from yours.

# %%
with tf.Session() as sess:

    # Run the initializer
    sess.run(tf.global_variables_initializer())
    
    for step in range(1, num_steps+1):

        #####
        # TODO
        # Get the next batch of MNIST data (only images are needed, not labels)
        # Generate noise to feed to the generator
        # Train
        #####
        
        if step % 1000 == 0 or step == 1:
            print('Step %i: Generator Loss: %f, Discriminator Loss: %f' % (step, gl, dl))
    
        # Generate images from noise, using the generator network.
        # TODO Change the variable names if they are different from yours.
        if step % 10000 == 0 or step == 1:
            f, a = plt.subplots(4, 10, figsize=(10, 4))
            for i in range(10):
                # Noise input.
                z = np.random.uniform(-1., 1., size=[4, noise_dim])
                g = sess.run([gen_sample], feed_dict={gen_input: z})
                g = np.reshape(g, newshape=(4, 28, 28, 1))
                # Reverse colours for better display
                g = -1 * (g - 1)
                for j in range(4):
                    # Generate image from noise. Extend to 3 channels for matplot figure.
                    img = np.reshape(np.repeat(g[j][:, :, np.newaxis], 3, axis=2),
                                     newshape=(28, 28, 3))
                    a[j][i].imshow(img)

            plt.draw()
            print('gan'+str(step)+'.png')
            plt.savefig('gan'+str(step)+'.png')
# Out:
# Step 1: Generator Loss: 0.645723, Discriminator Loss: 1.310875
# gan1.png
# Step 1000: Generator Loss: 4.050825, Discriminator Loss: 0.045055
# Step 2000: Generator Loss: 4.184691, Discriminator Loss: 0.053454
# Step 3000: Generator Loss: 5.421757, Discriminator Loss: 0.016621
# Step 4000: Generator Loss: 3.798069, Discriminator Loss: 0.037094
# Step 5000: Generator Loss: 3.864313, Discriminator Loss: 0.095495
# Step 6000: Generator Loss: 4.470815, Discriminator Loss: 0.048160
# Step 7000: Generator Loss: 4.339087, Discriminator Loss: 0.114698
# Step 8000: Generator Loss: 4.121165, Discriminator Loss: 0.077570
# Step 9000: Generator Loss: 4.747775, Discriminator Loss: 0.084910
# Step 10000: Generator Loss: 5.032366, Discriminator Loss: 0.116188
# gan10000.png
# Step 11000: Generator Loss: 4.475104, Discriminator Loss: 0.097629
# Step 12000: Generator Loss: 4.790847, Discriminator Loss: 0.128775
# Step 13000: Generator Loss: 5.186819, Discriminator Loss: 0.101345
# Step 14000: Generator Loss: 5.026080, Discriminator Loss: 0.125601
# Step 15000: Generator Loss: 4.652981, Discriminator Loss: 0.197704
# Step 16000: Generator Loss: 5.899688, Discriminator Loss: 0.130745
# Step 17000: Generator Loss: 4.719344, Discriminator Loss: 0.294866
# Step 18000: Generator Loss: 5.492733, Discriminator Loss: 0.041183
# Step 19000: Generator Loss: 5.992752, Discriminator Loss: 0.039279
# Step 20000: Generator Loss: 4.595977, Discriminator Loss: 0.109230
# gan20000.png
# Step 21000: Generator Loss: 4.701296, Discriminator Loss: 0.138011
# Step 22000: Generator Loss: 3.835589, Discriminator Loss: 0.275726
# Step 23000: Generator Loss: 3.858440, Discriminator Loss: 0.214418
# Step 24000: Generator Loss: 5.898464, Discriminator Loss: 0.048569
# Step 25000: Generator Loss: 5.167830, Discriminator Loss: 0.188931
# Step 26000: Generator Loss: 4.289401, Discriminator Loss: 0.434760
# Step 27000: Generator Loss: 4.809704, Discriminator Loss: 0.096810
# Step 28000: Generator Loss: 5.395491, Discriminator Loss: 0.123315
# Step 29000: Generator Loss: 3.350568, Discriminator Loss: 0.295457
# Step 30000: Generator Loss: 5.150574, Discriminator Loss: 0.124209
# gan30000.png
# Step 31000: Generator Loss: 4.825282, Discriminator Loss: 0.080530
# Step 32000: Generator Loss: 5.154515, Discriminator Loss: 0.054824
# Step 33000: Generator Loss: 4.406672, Discriminator Loss: 0.092816
# Step 34000: Generator Loss: 3.201118, Discriminator Loss: 0.342230
# Step 35000: Generator Loss: 3.640845, Discriminator Loss: 0.199297
# Step 36000: Generator Loss: 4.510084, Discriminator Loss: 0.182974
# Step 37000: Generator Loss: 3.178591, Discriminator Loss: 0.472523
# Step 38000: Generator Loss: 3.662494, Discriminator Loss: 0.262215
# Step 39000: Generator Loss: 2.966394, Discriminator Loss: 0.438410
# Step 40000: Generator Loss: 3.469384, Discriminator Loss: 0.395486
# gan40000.png
# Step 41000: Generator Loss: 3.299540, Discriminator Loss: 0.422543
# Step 42000: Generator Loss: 3.105390, Discriminator Loss: 0.338595
# Step 43000: Generator Loss: 2.947252, Discriminator Loss: 0.521465
# Step 44000: Generator Loss: 3.146739, Discriminator Loss: 0.378338
# Step 45000: Generator Loss: 2.653436, Discriminator Loss: 0.511126
# Step 46000: Generator Loss: 2.887242, Discriminator Loss: 0.533709
# Step 47000: Generator Loss: 3.123683, Discriminator Loss: 0.502563
# Step 48000: Generator Loss: 2.755248, Discriminator Loss: 0.485916
# Step 49000: Generator Loss: nan, Discriminator Loss: nan
# Step 50000: Generator Loss: nan, Discriminator Loss: nan
# gan50000.png
# Step 51000: Generator Loss: nan, Discriminator Loss: nan
# Step 52000: Generator Loss: nan, Discriminator Loss: nan
# Step 53000: Generator Loss: nan, Discriminator Loss: nan
# Step 54000: Generator Loss: nan, Discriminator Loss: nan
# Step 55000: Generator Loss: nan, Discriminator Loss: nan
# Step 56000: Generator Loss: nan, Discriminator Loss: nan
# Step 57000: Generator Loss: nan, Discriminator Loss: nan
# Step 58000: Generator Loss: nan, Discriminator Loss: nan
# Step 59000: Generator Loss: nan, Discriminator Loss: nan
# Step 60000: Generator Loss: nan, Discriminator Loss: nan
# gan60000.png
# Step 61000: Generator Loss: nan, Discriminator Loss: nan
# Step 62000: Generator Loss: nan, Discriminator Loss: nan
# Step 63000: Generator Loss: nan, Discriminator Loss: nan
# Step 64000: Generator Loss: nan, Discriminator Loss: nan
# Step 65000: Generator Loss: nan, Discriminator Loss: nan
# Step 66000: Generator Loss: nan, Discriminator Loss: nan
# Step 67000: Generator Loss: nan, Discriminator Loss: nan
# Step 68000: Generator Loss: nan, Discriminator Loss: nan
# Step 69000: Generator Loss: nan, Discriminator Loss: nan
# Step 70000: Generator Loss: nan, Discriminator Loss: nan
# gan70000.png
# Step 71000: Generator Loss: nan, Discriminator Loss: nan
# Step 72000: Generator Loss: nan, Discriminator Loss: nan
# Step 73000: Generator Loss: nan, Discriminator Loss: nan
# Step 74000: Generator Loss: nan, Discriminator Loss: nan
# Step 75000: Generator Loss: nan, Discriminator Loss: nan
# Step 76000: Generator Loss: nan, Discriminator Loss: nan
# Step 77000: Generator Loss: nan, Discriminator Loss: nan
# Step 78000: Generator Loss: nan, Discriminator Loss: nan
# Step 79000: Generator Loss: nan, Discriminator Loss: nan
# Step 80000: Generator Loss: nan, Discriminator Loss: nan
# gan80000.png
# Step 81000: Generator Loss: nan, Discriminator Loss: nan
# Step 82000: Generator Loss: nan, Discriminator Loss: nan
# Step 83000: Generator Loss: nan, Discriminator Loss: nan
# Step 84000: Generator Loss: nan, Discriminator Loss: nan
# Step 85000: Generator Loss: nan, Discriminator Loss: nan
# Step 86000: Generator Loss: nan, Discriminator Loss: nan
# Step 87000: Generator Loss: nan, Discriminator Loss: nan
# Step 88000: Generator Loss: nan, Discriminator Loss: nan
# Step 89000: Generator Loss: nan, Discriminator Loss: nan
# Step 90000: Generator Loss: nan, Discriminator Loss: nan
# gan90000.png
# Step 91000: Generator Loss: nan, Discriminator Loss: nan
# Step 92000: Generator Loss: nan, Discriminator Loss: nan
# Step 93000: Generator Loss: nan, Discriminator Loss: nan
# Step 94000: Generator Loss: nan, Discriminator Loss: nan
# Step 95000: Generator Loss: nan, Discriminator Loss: nan
# Step 96000: Generator Loss: nan, Discriminator Loss: nan
# Step 97000: Generator Loss: nan, Discriminator Loss: nan
# Step 98000: Generator Loss: nan, Discriminator Loss: nan
# Step 99000: Generator Loss: nan, Discriminator Loss: nan
# Step 100000: Generator Loss: nan, Discriminator Loss: nan
# gan100000.png
# Step 101000: Generator Loss: nan, Discriminator Loss: nan
# Step 102000: Generator Loss: nan, Discriminator Loss: nan
# Step 103000: Generator Loss: nan, Discriminator Loss: nan
# Step 104000: Generator Loss: nan, Discriminator Loss: nan
# Step 105000: Generator Loss: nan, Discriminator Loss: nan
# Step 106000: Generator Loss: nan, Discriminator Loss: nan
# Step 107000: Generator Loss: nan, Discriminator Loss: nan
# Step 108000: Generator Loss: nan, Discriminator Loss: nan
# Step 109000: Generator Loss: nan, Discriminator Loss: nan
# Step 110000: Generator Loss: nan, Discriminator Loss: nan
# gan110000.png
# Step 111000: Generator Loss: nan, Discriminator Loss: nan
# Step 112000: Generator Loss: nan, Discriminator Loss: nan
# Step 113000: Generator Loss: nan, Discriminator Loss: nan
# Step 114000: Generator Loss: nan, Discriminator Loss: nan
# Step 115000: Generator Loss: nan, Discriminator Loss: nan
# Step 116000: Generator Loss: nan, Discriminator Loss: nan
# Step 117000: Generator Loss: nan, Discriminator Loss: nan
# Step 118000: Generator Loss: nan, Discriminator Loss: nan
# Step 119000: Generator Loss: nan, Discriminator Loss: nan
# Step 120000: Generator Loss: nan, Discriminator Loss: nan
# gan120000.png
# Step 121000: Generator Loss: nan, Discriminator Loss: nan
# Step 122000: Generator Loss: nan, Discriminator Loss: nan
# Step 123000: Generator Loss: nan, Discriminator Loss: nan
# Step 124000: Generator Loss: nan, Discriminator Loss: nan
# Step 125000: Generator Loss: nan, Discriminator Loss: nan
# Step 126000: Generator Loss: nan, Discriminator Loss: nan
# Step 127000: Generator Loss: nan, Discriminator Loss: nan
# Step 128000: Generator Loss: nan, Discriminator Loss: nan
# Step 129000: Generator Loss: nan, Discriminator Loss: nan
# Step 130000: Generator Loss: nan, Discriminator Loss: nan
# gan130000.png
# Step 131000: Generator Loss: nan, Discriminator Loss: nan
# Step 132000: Generator Loss: nan, Discriminator Loss: nan
# Step 133000: Generator Loss: nan, Discriminator Loss: nan
# Step 134000: Generator Loss: nan, Discriminator Loss: nan
# Step 135000: Generator Loss: nan, Discriminator Loss: nan
# Step 136000: Generator Loss: nan, Discriminator Loss: nan
# Step 137000: Generator Loss: nan, Discriminator Loss: nan
# Step 138000: Generator Loss: nan, Discriminator Loss: nan
# Step 139000: Generator Loss: nan, Discriminator Loss: nan
# Step 140000: Generator Loss: nan, Discriminator Loss: nan
# gan140000.png
# Step 141000: Generator Loss: nan, Discriminator Loss: nan
# Step 142000: Generator Loss: nan, Discriminator Loss: nan
# Step 143000: Generator Loss: nan, Discriminator Loss: nan
# Step 144000: Generator Loss: nan, Discriminator Loss: nan
# Step 145000: Generator Loss: nan, Discriminator Loss: nan
# Step 146000: Generator Loss: nan, Discriminator Loss: nan
# Step 147000: Generator Loss: nan, Discriminator Loss: nan
# Step 148000: Generator Loss: nan, Discriminator Loss: nan
# Step 149000: Generator Loss: nan, Discriminator Loss: nan
# Step 150000: Generator Loss: nan, Discriminator Loss: nan
# gan150000.png
# Step 151000: Generator Loss: nan, Discriminator Loss: nan
# Step 152000: Generator Loss: nan, Discriminator Loss: nan
# Step 153000: Generator Loss: nan, Discriminator Loss: nan
# Step 154000: Generator Loss: nan, Discriminator Loss: nan
# Step 155000: Generator Loss: nan, Discriminator Loss: nan
# Step 156000: Generator Loss: nan, Discriminator Loss: nan
# Step 157000: Generator Loss: nan, Discriminator Loss: nan
# Step 158000: Generator Loss: nan, Discriminator Loss: nan
# Step 159000: Generator Loss: nan, Discriminator Loss: nan
# Step 160000: Generator Loss: nan, Discriminator Loss: nan
# gan160000.png
# Step 161000: Generator Loss: nan, Discriminator Loss: nan
# Step 162000: Generator Loss: nan, Discriminator Loss: nan
# Step 163000: Generator Loss: nan, Discriminator Loss: nan
# Step 164000: Generator Loss: nan, Discriminator Loss: nan
# Step 165000: Generator Loss: nan, Discriminator Loss: nan
# Step 166000: Generator Loss: nan, Discriminator Loss: nan
# Step 167000: Generator Loss: nan, Discriminator Loss: nan
# Step 168000: Generator Loss: nan, Discriminator Loss: nan
# Step 169000: Generator Loss: nan, Discriminator Loss: nan
# Step 170000: Generator Loss: nan, Discriminator Loss: nan
# gan170000.png
# Step 171000: Generator Loss: nan, Discriminator Loss: nan
# Step 172000: Generator Loss: nan, Discriminator Loss: nan
# Step 173000: Generator Loss: nan, Discriminator Loss: nan
# Step 174000: Generator Loss: nan, Discriminator Loss: nan
# Step 175000: Generator Loss: nan, Discriminator Loss: nan
# Step 176000: Generator Loss: nan, Discriminator Loss: nan
# Step 177000: Generator Loss: nan, Discriminator Loss: nan
# Step 178000: Generator Loss: nan, Discriminator Loss: nan
# Step 179000: Generator Loss: nan, Discriminator Loss: nan
# Step 180000: Generator Loss: nan, Discriminator Loss: nan
# gan180000.png
# Step 181000: Generator Loss: nan, Discriminator Loss: nan
# Step 182000: Generator Loss: nan, Discriminator Loss: nan
# Step 183000: Generator Loss: nan, Discriminator Loss: nan
# Step 184000: Generator Loss: nan, Discriminator Loss: nan
# Step 185000: Generator Loss: nan, Discriminator Loss: nan
# Step 186000: Generator Loss: nan, Discriminator Loss: nan
# Step 187000: Generator Loss: nan, Discriminator Loss: nan
# Step 188000: Generator Loss: nan, Discriminator Loss: nan
# Step 189000: Generator Loss: nan, Discriminator Loss: nan
# Step 190000: Generator Loss: nan, Discriminator Loss: nan
# gan190000.png
# Step 191000: Generator Loss: nan, Discriminator Loss: nan
# Step 192000: Generator Loss: nan, Discriminator Loss: nan
# Step 193000: Generator Loss: nan, Discriminator Loss: nan
# Step 194000: Generator Loss: nan, Discriminator Loss: nan
# Step 195000: Generator Loss: nan, Discriminator Loss: nan
# Step 196000: Generator Loss: nan, Discriminator Loss: nan
# Step 197000: Generator Loss: nan, Discriminator Loss: nan
# Step 198000: Generator Loss: nan, Discriminator Loss: nan
# Step 199000: Generator Loss: nan, Discriminator Loss: nan
# Step 200000: Generator Loss: nan, Discriminator Loss: nan
# /Users/kojin/anaconda/envs/tensorflow_workshop/lib/python3.6/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# gan200000.png
# Step 201000: Generator Loss: nan, Discriminator Loss: nan
# Step 202000: Generator Loss: nan, Discriminator Loss: nan
# Step 203000: Generator Loss: nan, Discriminator Loss: nan
# Step 204000: Generator Loss: nan, Discriminator Loss: nan
# Step 205000: Generator Loss: nan, Discriminator Loss: nan
# Step 206000: Generator Loss: nan, Discriminator Loss: nan
# Step 207000: Generator Loss: nan, Discriminator Loss: nan
# Step 208000: Generator Loss: nan, Discriminator Loss: nan
# Step 209000: Generator Loss: nan, Discriminator Loss: nan
# Step 210000: Generator Loss: nan, Discriminator Loss: nan
# gan210000.png
# Step 211000: Generator Loss: nan, Discriminator Loss: nan
# Step 212000: Generator Loss: nan, Discriminator Loss: nan
# Step 213000: Generator Loss: nan, Discriminator Loss: nan
# Step 214000: Generator Loss: nan, Discriminator Loss: nan
# Step 215000: Generator Loss: nan, Discriminator Loss: nan
# Step 216000: Generator Loss: nan, Discriminator Loss: nan
# Step 217000: Generator Loss: nan, Discriminator Loss: nan
# Step 218000: Generator Loss: nan, Discriminator Loss: nan
# Step 219000: Generator Loss: nan, Discriminator Loss: nan
# Step 220000: Generator Loss: nan, Discriminator Loss: nan
# gan220000.png
# Step 221000: Generator Loss: nan, Discriminator Loss: nan
# Step 222000: Generator Loss: nan, Discriminator Loss: nan
# Step 223000: Generator Loss: nan, Discriminator Loss: nan
# Step 224000: Generator Loss: nan, Discriminator Loss: nan
# Step 225000: Generator Loss: nan, Discriminator Loss: nan
# Step 226000: Generator Loss: nan, Discriminator Loss: nan
# Step 227000: Generator Loss: nan, Discriminator Loss: nan
# Step 228000: Generator Loss: nan, Discriminator Loss: nan
# Step 229000: Generator Loss: nan, Discriminator Loss: nan
# Step 230000: Generator Loss: nan, Discriminator Loss: nan
# gan230000.png
# Step 231000: Generator Loss: nan, Discriminator Loss: nan
# Step 232000: Generator Loss: nan, Discriminator Loss: nan
# Step 233000: Generator Loss: nan, Discriminator Loss: nan
# Step 234000: Generator Loss: nan, Discriminator Loss: nan
# Step 235000: Generator Loss: nan, Discriminator Loss: nan
# Step 236000: Generator Loss: nan, Discriminator Loss: nan
# Step 237000: Generator Loss: nan, Discriminator Loss: nan
# Step 238000: Generator Loss: nan, Discriminator Loss: nan
# Step 239000: Generator Loss: nan, Discriminator Loss: nan
# Step 240000: Generator Loss: nan, Discriminator Loss: nan
# gan240000.png
# Step 241000: Generator Loss: nan, Discriminator Loss: nan
# Step 242000: Generator Loss: nan, Discriminator Loss: nan
# Step 243000: Generator Loss: nan, Discriminator Loss: nan
# Step 244000: Generator Loss: nan, Discriminator Loss: nan
# Step 245000: Generator Loss: nan, Discriminator Loss: nan
# Step 246000: Generator Loss: nan, Discriminator Loss: nan
# Step 247000: Generator Loss: nan, Discriminator Loss: nan
# Step 248000: Generator Loss: nan, Discriminator Loss: nan
# Step 249000: Generator Loss: nan, Discriminator Loss: nan
# Step 250000: Generator Loss: nan, Discriminator Loss: nan
# gan250000.png
# Step 251000: Generator Loss: nan, Discriminator Loss: nan
# Step 252000: Generator Loss: nan, Discriminator Loss: nan
# Step 253000: Generator Loss: nan, Discriminator Loss: nan
# Step 254000: Generator Loss: nan, Discriminator Loss: nan
# Step 255000: Generator Loss: nan, Discriminator Loss: nan
# Step 256000: Generator Loss: nan, Discriminator Loss: nan
# Step 257000: Generator Loss: nan, Discriminator Loss: nan
# Step 258000: Generator Loss: nan, Discriminator Loss: nan
# Step 259000: Generator Loss: nan, Discriminator Loss: nan
# Step 260000: Generator Loss: nan, Discriminator Loss: nan
# gan260000.png
# Step 261000: Generator Loss: nan, Discriminator Loss: nan
# Step 262000: Generator Loss: nan, Discriminator Loss: nan
# Step 263000: Generator Loss: nan, Discriminator Loss: nan
# Step 264000: Generator Loss: nan, Discriminator Loss: nan
# Step 265000: Generator Loss: nan, Discriminator Loss: nan
# Step 266000: Generator Loss: nan, Discriminator Loss: nan
# Step 267000: Generator Loss: nan, Discriminator Loss: nan
# Step 268000: Generator Loss: nan, Discriminator Loss: nan
# Step 269000: Generator Loss: nan, Discriminator Loss: nan
# Step 270000: Generator Loss: nan, Discriminator Loss: nan
# gan270000.png
# Step 271000: Generator Loss: nan, Discriminator Loss: nan
# Step 272000: Generator Loss: nan, Discriminator Loss: nan
# Step 273000: Generator Loss: nan, Discriminator Loss: nan
# Step 274000: Generator Loss: nan, Discriminator Loss: nan
# Step 275000: Generator Loss: nan, Discriminator Loss: nan
# Step 276000: Generator Loss: nan, Discriminator Loss: nan
# Step 277000: Generator Loss: nan, Discriminator Loss: nan
# Step 278000: Generator Loss: nan, Discriminator Loss: nan
# Step 279000: Generator Loss: nan, Discriminator Loss: nan
# Step 280000: Generator Loss: nan, Discriminator Loss: nan
# gan280000.png
# Step 281000: Generator Loss: nan, Discriminator Loss: nan
# Step 282000: Generator Loss: nan, Discriminator Loss: nan
# Step 283000: Generator Loss: nan, Discriminator Loss: nan
# Step 284000: Generator Loss: nan, Discriminator Loss: nan
# Step 285000: Generator Loss: nan, Discriminator Loss: nan
# Step 286000: Generator Loss: nan, Discriminator Loss: nan
# Step 287000: Generator Loss: nan, Discriminator Loss: nan
# Step 288000: Generator Loss: nan, Discriminator Loss: nan
# Step 289000: Generator Loss: nan, Discriminator Loss: nan
# Step 290000: Generator Loss: nan, Discriminator Loss: nan
# gan290000.png
# Step 291000: Generator Loss: nan, Discriminator Loss: nan
# Step 292000: Generator Loss: nan, Discriminator Loss: nan
# Step 293000: Generator Loss: nan, Discriminator Loss: nan
# Step 294000: Generator Loss: nan, Discriminator Loss: nan
# Step 295000: Generator Loss: nan, Discriminator Loss: nan
# Step 296000: Generator Loss: nan, Discriminator Loss: nan
# Step 297000: Generator Loss: nan, Discriminator Loss: nan
# Step 298000: Generator Loss: nan, Discriminator Loss: nan
# Step 299000: Generator Loss: nan, Discriminator Loss: nan
# Step 300000: Generator Loss: nan, Discriminator Loss: nan
# gan300000.png
# Step 301000: Generator Loss: nan, Discriminator Loss: nan
# Step 302000: Generator Loss: nan, Discriminator Loss: nan
# Step 303000: Generator Loss: nan, Discriminator Loss: nan
# Step 304000: Generator Loss: nan, Discriminator Loss: nan
# Step 305000: Generator Loss: nan, Discriminator Loss: nan
# Step 306000: Generator Loss: nan, Discriminator Loss: nan
# Step 307000: Generator Loss: nan, Discriminator Loss: nan
# Step 308000: Generator Loss: nan, Discriminator Loss: nan
# Step 309000: Generator Loss: nan, Discriminator Loss: nan
# Step 310000: Generator Loss: nan, Discriminator Loss: nan
# gan310000.png
# Step 311000: Generator Loss: nan, Discriminator Loss: nan
# Step 312000: Generator Loss: nan, Discriminator Loss: nan
# Step 313000: Generator Loss: nan, Discriminator Loss: nan
# Step 314000: Generator Loss: nan, Discriminator Loss: nan
# Step 315000: Generator Loss: nan, Discriminator Loss: nan
# Step 316000: Generator Loss: nan, Discriminator Loss: nan
# Step 317000: Generator Loss: nan, Discriminator Loss: nan
# Step 318000: Generator Loss: nan, Discriminator Loss: nan
# Step 319000: Generator Loss: nan, Discriminator Loss: nan
# Step 320000: Generator Loss: nan, Discriminator Loss: nan
# gan320000.png
# Step 321000: Generator Loss: nan, Discriminator Loss: nan
# Step 322000: Generator Loss: nan, Discriminator Loss: nan
# Step 323000: Generator Loss: nan, Discriminator Loss: nan
# Step 324000: Generator Loss: nan, Discriminator Loss: nan
# Step 325000: Generator Loss: nan, Discriminator Loss: nan
# Step 326000: Generator Loss: nan, Discriminator Loss: nan
# Step 327000: Generator Loss: nan, Discriminator Loss: nan
# Step 328000: Generator Loss: nan, Discriminator Loss: nan
# Step 329000: Generator Loss: nan, Discriminator Loss: nan
# Step 330000: Generator Loss: nan, Discriminator Loss: nan
# gan330000.png
# Step 331000: Generator Loss: nan, Discriminator Loss: nan
# Step 332000: Generator Loss: nan, Discriminator Loss: nan
# Step 333000: Generator Loss: nan, Discriminator Loss: nan
# Step 334000: Generator Loss: nan, Discriminator Loss: nan
# Step 335000: Generator Loss: nan, Discriminator Loss: nan
# Step 336000: Generator Loss: nan, Discriminator Loss: nan
# Step 337000: Generator Loss: nan, Discriminator Loss: nan
# Step 338000: Generator Loss: nan, Discriminator Loss: nan
# Step 339000: Generator Loss: nan, Discriminator Loss: nan
# Step 340000: Generator Loss: nan, Discriminator Loss: nan
# gan340000.png
# Step 341000: Generator Loss: nan, Discriminator Loss: nan
# Step 342000: Generator Loss: nan, Discriminator Loss: nan
# Step 343000: Generator Loss: nan, Discriminator Loss: nan
# Step 344000: Generator Loss: nan, Discriminator Loss: nan
# Step 345000: Generator Loss: nan, Discriminator Loss: nan
# Step 346000: Generator Loss: nan, Discriminator Loss: nan
# Step 347000: Generator Loss: nan, Discriminator Loss: nan
# Step 348000: Generator Loss: nan, Discriminator Loss: nan
# Step 349000: Generator Loss: nan, Discriminator Loss: nan
# Step 350000: Generator Loss: nan, Discriminator Loss: nan
# gan350000.png
# Step 351000: Generator Loss: nan, Discriminator Loss: nan
# Step 352000: Generator Loss: nan, Discriminator Loss: nan
# Step 353000: Generator Loss: nan, Discriminator Loss: nan
# Step 354000: Generator Loss: nan, Discriminator Loss: nan
# Step 355000: Generator Loss: nan, Discriminator Loss: nan
# Step 356000: Generator Loss: nan, Discriminator Loss: nan
# Step 357000: Generator Loss: nan, Discriminator Loss: nan
# Step 358000: Generator Loss: nan, Discriminator Loss: nan
# Step 359000: Generator Loss: nan, Discriminator Loss: nan
# Step 360000: Generator Loss: nan, Discriminator Loss: nan
# gan360000.png
# Step 361000: Generator Loss: nan, Discriminator Loss: nan
# Step 362000: Generator Loss: nan, Discriminator Loss: nan
# Step 363000: Generator Loss: nan, Discriminator Loss: nan
# Step 364000: Generator Loss: nan, Discriminator Loss: nan
# Step 365000: Generator Loss: nan, Discriminator Loss: nan
# Step 366000: Generator Loss: nan, Discriminator Loss: nan
# Step 367000: Generator Loss: nan, Discriminator Loss: nan
# Step 368000: Generator Loss: nan, Discriminator Loss: nan
# Step 369000: Generator Loss: nan, Discriminator Loss: nan
# Step 370000: Generator Loss: nan, Discriminator Loss: nan
# gan370000.png
# Step 371000: Generator Loss: nan, Discriminator Loss: nan
# Step 372000: Generator Loss: nan, Discriminator Loss: nan
# Step 373000: Generator Loss: nan, Discriminator Loss: nan
# Step 374000: Generator Loss: nan, Discriminator Loss: nan
# Step 375000: Generator Loss: nan, Discriminator Loss: nan
# Step 376000: Generator Loss: nan, Discriminator Loss: nan
# Step 377000: Generator Loss: nan, Discriminator Loss: nan
# Step 378000: Generator Loss: nan, Discriminator Loss: nan
# Step 379000: Generator Loss: nan, Discriminator Loss: nan
# Step 380000: Generator Loss: nan, Discriminator Loss: nan
# gan380000.png
# Step 381000: Generator Loss: nan, Discriminator Loss: nan
# Step 382000: Generator Loss: nan, Discriminator Loss: nan
# Step 383000: Generator Loss: nan, Discriminator Loss: nan
# Step 384000: Generator Loss: nan, Discriminator Loss: nan
# Step 385000: Generator Loss: nan, Discriminator Loss: nan
# Step 386000: Generator Loss: nan, Discriminator Loss: nan
# Step 387000: Generator Loss: nan, Discriminator Loss: nan
# Step 388000: Generator Loss: nan, Discriminator Loss: nan
# Step 389000: Generator Loss: nan, Discriminator Loss: nan
# Step 390000: Generator Loss: nan, Discriminator Loss: nan
# gan390000.png
# Step 391000: Generator Loss: nan, Discriminator Loss: nan
# Step 392000: Generator Loss: nan, Discriminator Loss: nan
# Step 393000: Generator Loss: nan, Discriminator Loss: nan
# Step 394000: Generator Loss: nan, Discriminator Loss: nan
# Step 395000: Generator Loss: nan, Discriminator Loss: nan
# Step 396000: Generator Loss: nan, Discriminator Loss: nan
# Step 397000: Generator Loss: nan, Discriminator Loss: nan
# Step 398000: Generator Loss: nan, Discriminator Loss: nan
# Step 399000: Generator Loss: nan, Discriminator Loss: nan
# Step 400000: Generator Loss: nan, Discriminator Loss: nan
# gan400000.png
# Step 401000: Generator Loss: nan, Discriminator Loss: nan
# Step 402000: Generator Loss: nan, Discriminator Loss: nan
# Step 403000: Generator Loss: nan, Discriminator Loss: nan
# Step 404000: Generator Loss: nan, Discriminator Loss: nan
# Step 405000: Generator Loss: nan, Discriminator Loss: nan
# Step 406000: Generator Loss: nan, Discriminator Loss: nan
# Step 407000: Generator Loss: nan, Discriminator Loss: nan
# Step 408000: Generator Loss: nan, Discriminator Loss: nan
# Step 409000: Generator Loss: nan, Discriminator Loss: nan
# Step 410000: Generator Loss: nan, Discriminator Loss: nan
# gan410000.png
# Step 411000: Generator Loss: nan, Discriminator Loss: nan
# Step 412000: Generator Loss: nan, Discriminator Loss: nan
# Step 413000: Generator Loss: nan, Discriminator Loss: nan
# Step 414000: Generator Loss: nan, Discriminator Loss: nan
# Step 415000: Generator Loss: nan, Discriminator Loss: nan
# Step 416000: Generator Loss: nan, Discriminator Loss: nan
# Step 417000: Generator Loss: nan, Discriminator Loss: nan
# Step 418000: Generator Loss: nan, Discriminator Loss: nan
# Step 419000: Generator Loss: nan, Discriminator Loss: nan
# Step 420000: Generator Loss: nan, Discriminator Loss: nan
# gan420000.png
# Step 421000: Generator Loss: nan, Discriminator Loss: nan
# Step 422000: Generator Loss: nan, Discriminator Loss: nan
# Step 423000: Generator Loss: nan, Discriminator Loss: nan
# Step 424000: Generator Loss: nan, Discriminator Loss: nan
# Step 425000: Generator Loss: nan, Discriminator Loss: nan
# Step 426000: Generator Loss: nan, Discriminator Loss: nan
# Step 427000: Generator Loss: nan, Discriminator Loss: nan
# Step 428000: Generator Loss: nan, Discriminator Loss: nan
# Step 429000: Generator Loss: nan, Discriminator Loss: nan
# Step 430000: Generator Loss: nan, Discriminator Loss: nan
# gan430000.png
# Step 431000: Generator Loss: nan, Discriminator Loss: nan
# Step 432000: Generator Loss: nan, Discriminator Loss: nan
# Step 433000: Generator Loss: nan, Discriminator Loss: nan
# Step 434000: Generator Loss: nan, Discriminator Loss: nan
# Step 435000: Generator Loss: nan, Discriminator Loss: nan
# Step 436000: Generator Loss: nan, Discriminator Loss: nan
# Step 437000: Generator Loss: nan, Discriminator Loss: nan
# Step 438000: Generator Loss: nan, Discriminator Loss: nan
# Step 439000: Generator Loss: nan, Discriminator Loss: nan
# Step 440000: Generator Loss: nan, Discriminator Loss: nan
# gan440000.png
# Step 441000: Generator Loss: nan, Discriminator Loss: nan
# Step 442000: Generator Loss: nan, Discriminator Loss: nan
# Step 443000: Generator Loss: nan, Discriminator Loss: nan
# Step 444000: Generator Loss: nan, Discriminator Loss: nan
# Step 445000: Generator Loss: nan, Discriminator Loss: nan
# Step 446000: Generator Loss: nan, Discriminator Loss: nan
# Step 447000: Generator Loss: nan, Discriminator Loss: nan
# Step 448000: Generator Loss: nan, Discriminator Loss: nan
# Step 449000: Generator Loss: nan, Discriminator Loss: nan
# Step 450000: Generator Loss: nan, Discriminator Loss: nan
# gan450000.png
# Step 451000: Generator Loss: nan, Discriminator Loss: nan
# Step 452000: Generator Loss: nan, Discriminator Loss: nan
# Step 453000: Generator Loss: nan, Discriminator Loss: nan
# Step 454000: Generator Loss: nan, Discriminator Loss: nan
# Step 455000: Generator Loss: nan, Discriminator Loss: nan
# Step 456000: Generator Loss: nan, Discriminator Loss: nan
# Step 457000: Generator Loss: nan, Discriminator Loss: nan
# Step 458000: Generator Loss: nan, Discriminator Loss: nan
# Step 459000: Generator Loss: nan, Discriminator Loss: nan
# Step 460000: Generator Loss: nan, Discriminator Loss: nan
# gan460000.png
# Step 461000: Generator Loss: nan, Discriminator Loss: nan
# Step 462000: Generator Loss: nan, Discriminator Loss: nan
# Step 463000: Generator Loss: nan, Discriminator Loss: nan
# Step 464000: Generator Loss: nan, Discriminator Loss: nan
# Step 465000: Generator Loss: nan, Discriminator Loss: nan
# Step 466000: Generator Loss: nan, Discriminator Loss: nan
# Step 467000: Generator Loss: nan, Discriminator Loss: nan
# Step 468000: Generator Loss: nan, Discriminator Loss: nan
# Step 469000: Generator Loss: nan, Discriminator Loss: nan
# Step 470000: Generator Loss: nan, Discriminator Loss: nan
# gan470000.png
# Step 471000: Generator Loss: nan, Discriminator Loss: nan
# Step 472000: Generator Loss: nan, Discriminator Loss: nan
# Step 473000: Generator Loss: nan, Discriminator Loss: nan
# Step 474000: Generator Loss: nan, Discriminator Loss: nan
# Step 475000: Generator Loss: nan, Discriminator Loss: nan
# Step 476000: Generator Loss: nan, Discriminator Loss: nan
# Step 477000: Generator Loss: nan, Discriminator Loss: nan
# Step 478000: Generator Loss: nan, Discriminator Loss: nan
# Step 479000: Generator Loss: nan, Discriminator Loss: nan
# Step 480000: Generator Loss: nan, Discriminator Loss: nan
# gan480000.png
# Step 481000: Generator Loss: nan, Discriminator Loss: nan
# Step 482000: Generator Loss: nan, Discriminator Loss: nan
# Step 483000: Generator Loss: nan, Discriminator Loss: nan
# Step 484000: Generator Loss: nan, Discriminator Loss: nan
# Step 485000: Generator Loss: nan, Discriminator Loss: nan
# Step 486000: Generator Loss: nan, Discriminator Loss: nan
# Step 487000: Generator Loss: nan, Discriminator Loss: nan
# Step 488000: Generator Loss: nan, Discriminator Loss: nan
# Step 489000: Generator Loss: nan, Discriminator Loss: nan
# Step 490000: Generator Loss: nan, Discriminator Loss: nan
# gan490000.png
# Step 491000: Generator Loss: nan, Discriminator Loss: nan
# Step 492000: Generator Loss: nan, Discriminator Loss: nan
# Step 493000: Generator Loss: nan, Discriminator Loss: nan
# Step 494000: Generator Loss: nan, Discriminator Loss: nan
# Step 495000: Generator Loss: nan, Discriminator Loss: nan
# Step 496000: Generator Loss: nan, Discriminator Loss: nan
# Step 497000: Generator Loss: nan, Discriminator Loss: nan
# Step 498000: Generator Loss: nan, Discriminator Loss: nan
# Step 499000: Generator Loss: nan, Discriminator Loss: nan
# Step 500000: Generator Loss: nan, Discriminator Loss: nan
# gan500000.png

# %% [markdown]
# ### 7. [Optional] use TensorBoard to check the computation graph and loss.
# You might want to read about [variable sharing](https://www.tensorflow.org/versions/r1.1/programmers_guide/variable_scope) and [variable scope](https://stackoverflow.com/questions/35919020/whats-the-difference-of-name-scope-and-a-variable-scope-in-tensorflow).
#
# This might be a bit more involved than the previous steps...

# %% [markdown]
# Ok, this was probably the hardest section so far since there's less hand holding. But if you could complete this exercise, this means that you can build reasonably sophisticated neural network models in TensorFlow! Look back and see how far you got :)
#
# Check [this](https://github.com/tensorflow/models/blob/master/research/gan/tutorial.ipynb) out if you're more interested in GANs.
#
# Thanks for completing this workshop. If you liked it, please `star` this repo, so that more and more people can learn about TensorFlow! Feedback is always welcome!
